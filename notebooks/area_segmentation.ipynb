# %%
import cv2
from PIL import Image
import numpy as np
import os
import matplotlib.pyplot as plt

# %% [markdown]
# Load and Display Image

# %%
# Load the image RGB
image = cv2.imread('../data/cropped/cropped_image.jpg')
color_image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  

# Show image
plt.imshow(color_image)
plt.show()

# %% [markdown]
# Area segmentation on red scoring areas

# %%
hsv_image = cv2.cvtColor(color_image, cv2.COLOR_RGB2HSV)

light_red = np.array([120,22,22])
dark_red = np.array([75,21,21])
mask = cv2.inRange(hsv_image, light_red, dark_red)
result = cv2.bitwise_and(image, image, mask=mask)
#result = cv2.GaussianBlur(result, (7, 7), 0)
plt.imshow(result)
plt.show()


# kernel = np.ones((5,5), np.uint8)
# opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

# contours, hierarchy = cv2.findContours(opening, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# cv2.drawContours(image, contours, -1, (0, 255, 0), 2)
